# %%
data00001_acc = [26.5,
38.7,
50.8,
56.4,
60.3,
62.3,
63.2,
65.1,
65.8,
66.5]

data00001_loss = [0.194304,
0.167685,
0.133568,
0.115056,
0.104707,
0.097655,
0.095498,
0.091026,
0.087776,
0.085201]

# %%
import matplotlib.pyplot as plt

x = range(1, 11)
y = data00001_acc


plt.figure(figsize=(10, 6))  # Increase the figure size to 10 inches by 6 inches
plt.plot(x, y)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model with 0.0001 learning rate')
plt.savefig('00001_acc.png')
plt.show()

# %%
x = range(1, 11)
y = data00001_loss


plt.figure(figsize=(10, 6))  # Increase the figure size to 10 inches by 6 inches
plt.plot(x, y)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model with 0.0001 learning rate')
plt.savefig('00001_loss.png')
plt.show()
