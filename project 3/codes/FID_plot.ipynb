# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
input_data = np.array([
324.2850,
337.2980,
256.7732,
219.3080,
224.7098,
199.3129,
159.1759,
141.6697,
132.1554,
168.8268,
143.4216,
136.8419,
119.5462,
114.2566,
112.8088,
127.3280,
113.4581,
86.89005,
109.1610,
112.8840,
78.88924,
77.34264,
85.36579,
93.19448,
104.8934,
110.0168,
93.40984,
91.88947,
99.38217,
86.41064,
85.47253
])

# %%
plt.figure(figsize=(15, 7.5))
plt.plot(np.array(range(0, 31, 1)) * 10, input_data)
plt.xlabel("Epochs")
plt.ylabel("FID")
plt.title("FID of the results of GAN model while training")
plt.show()
